# %%
import pandas as pd

# %%
df0 = pd.read_csv("./data/praticiens.txt", sep="|", header=0)
# Out:
# C:\Users\stlon\AppData\Local\Temp\ipykernel_71876\923058764.py:1: DtypeWarning: Columns (0: Code civilité d'exercice, 1: Libellé civilité d'exercice, 2: Code type savoir-faire, 3: Libellé type savoir-faire, 4: Code savoir-faire, 5: Libellé savoir-faire, 6: Numéro FINESS site, 7: Numéro FINESS établissement juridique, 8: Code postal (coord. structure), 9: Téléphone 2 (coord. structure), 10: Télécopie (coord. structure), 11: Ancien identifiant de la structure, 12: Code section tableau pharmaciens, 13: Libellé section tableau pharmaciens) have mixed types. Specify dtype option on import or set low_memory=False.
#   df0 = pd.read_csv("./data/praticiens.txt", sep="|", header=0)

# %%
df0.dtypes
# Out:
# Type d'identifiant PP                                 int64
# Identifiant PP                                        int64
# Identification nationale PP                           int64
# Code civilité d'exercice                                str
# Libellé civilité d'exercice                             str
# Code civilité                                           str
# Libellé civilité                                        str
# Nom d'exercice                                          str
# Prénom d'exercice                                       str
# Code profession                                       int64
# Libellé profession                                      str
# Code catégorie professionnelle                          str
# Libellé catégorie professionnelle                       str
# Code type savoir-faire                                  str
# Libellé type savoir-faire                               str
# Code savoir-faire                                       str
# Libellé savoir-faire                                    str
# Code mode exercice                                      str
# Libellé mode exercice                                   str
# Numéro SIRET site                                   float64
# Numéro SIREN site                                   float64
# Numéro FINESS site                                   object
# Numéro FINESS établissement juridique                object
# Identifiant technique de la structure                   str
# Raison sociale site                                     str
# Enseigne commerciale site                               str
# Complément destinataire (coord. structure)              str
# Complément point géographique (coord. structure)        str
# Numéro Voie (coord. structure)                      float64
# Indice répétition voie (coord. structure)               str
# Code type de voie (coord. structure)                    str
# Libellé type de voie (coord. structure)                 str
# Libellé Voie (coord. structure)                         str
# Mention distribution (coord. structure)                 str
# Bureau cedex (coord. structure)                         str
# Code postal (coord. structure)                       object
# Code commune (coord. structure)                         str
# Libellé commune (coord. structure)                      str
# Code pays (coord. structure)                        float64
# Libellé pays (coord. structure)                         str
# Téléphone (coord. structure)                            str
# Téléphone 2 (coord. structure)                       object
# Télécopie (coord. structure)                         object
# Adresse e-mail (coord. structure)                       str
# Code Département (structure)                        float64
# Libellé Département (structure)                     float64
# Ancien identifiant de la structure                   object
# Autorité d'enregistrement                               str
# Code secteur d'activité                                 str
# Libellé secteur d'activité                              str
# Code section tableau pharmaciens                        str
# Libellé section tableau pharmaciens                     str
# Code rôle                                               str
# Libellé rôle                                            str
# Code genre activité                                     str
# Libellé genre activité                                  str
# dtype: object

# %%
dtype = {
    "Libellé civilité d'exercice": "str",
    "Libellé savoir-faire": "str",
    "Code postal (coord. structure)": "str",
}

df = pd.read_csv(
    "./data/praticiens.txt",
    sep="|",
    header=0,
    dtype=dtype,
    usecols=[
        "Libellé civilité d'exercice",
        "Libellé civilité",
        "Nom d'exercice",
        "Prénom d'exercice",
        "Libellé profession",
        "Libellé savoir-faire",
        "Code mode exercice",
        "Numéro Voie (coord. structure)",
        "Libellé type de voie (coord. structure)",
        "Libellé Voie (coord. structure)",
        "Code postal (coord. structure)",
        "Libellé commune (coord. structure)",
        "Libellé secteur d'activité",
    ],
)

# %%
medecins = df[df["Libellé profession"] == "Médecin"]

# %%
medecins["Libellé savoir-faire"].unique()
# Out:
# <StringArray>
# [                                                        'Médecine Générale',
#                                              'Qualifié en Médecine Générale',
#                                           'Spécialiste en Médecine Générale',
#                                          'Médecine physique et réadaptation',
#                                                              'Ophtalmologie',
#                                                                'Psychiatrie',
#                                        'Gynécologie médicale et obstétrique',
#                                                     'Anesthesie-réanimation',
#                                          'Gastro-entérologie et hépatologie',
#                                    'Chirurgie orthopédique et traumatologie',
#                                                        'Médecine du travail',
#                                                        'Médecine vasculaire',
#                                                         'Chirurgie générale',
#                                                     'Oto-rhino-laryngologie',
#                                        'Cardiologie et maladies vasculaires',
#                                               'Dermatologie et vénéréologie',
#                                                            'Neuro-chirurgie',
#                                                         'Médecine d'urgence',
#                                                                  'Pédiatrie',
#                                                           'Radio-diagnostic',
#                                                                 'Neurologie',
#                                         'Santé publique et médecine sociale',
#                          'Chirurgie plastique reconstructrice et esthétique',
#                                                    'Gynécologie-obstétrique',
#                                                                'Pneumologie',
#                                              'Endocrinologie et métabolisme',
#                                        'Anatomie et cytologie pathologiques',
#                                                               'Stomatologie',
#                                                                'Obstétrique',
#                                                               'Rhumatologie',
#                                                       'Gynécologie médicale',
#                                                          'Neuro-psychiatrie',
#                                                  'Oncologie option médicale',
#                                                           'Médecine interne',
#                                     'Psychiatrie option enfant & adolescent',
#                                                         'Médecine nucléaire',
#                                                                'Néphrologie',
#                                                       'Chirurgie urologique',
#                                                                  'Gériatrie',
#                                                          'Biologie médicale',
#                                  'Chirurgie thoracique et cardio-vasculaire',
#                                                         'Génétique médicale',
#                                           'Chirurgie viscérale et digestive',
#                                                               'Allergologie',
#                                                       'Chirurgie vasculaire',
#                                  'Chirurgie maxillo-faciale et stomatologie',
#                                       'Hématologie (option Maladie du sang)',
#                                   'Médecine interne et immunologie clinique',
#                        'Chirurgie pédiatrique option orthopédie pédiatrique',
#                                                                'Hématologie',
#                                                            'CHIRURGIE ORALE',
#                                             'Médecine intensive-réanimation',
#                                                            'Radio-thérapie ',
#                                             'Oncologie option radiothérapie',
#                                                                   'Urologie',
#                                                        'Chirurgie infantile',
#                                        'Oncologie (option onco-hématologie)',
#                                                  'Chirurgie maxillo-faciale',
#                                    'Médecine légale et expertises médicales',
#                                    'Psychiatrie option enfant et adolescent',
#                                                          'Qualification PAC',
#                         'Radiologie et imagerie médicale opt radio inter av',
#                                        'Maladies infectieuses et tropicales',
#                                    'Endocrinologie, diabétologie, nutrition',
#                                                         'Recherche médicale',
#                                         'O.R.L et chirurgie cervico faciale',
#                                                 'Hématologie (réforme 2017)',
#                   'Gynéco-obstétrique et Gynéco médicale option Gynéco-obst',
#                                   'Chirurgie maxillo-faciale (réforme 2017)',
#                                      'Hématologie (option Onco-hématologie)',
#               'Gynéco-obstétrique et Gynéco médicale option Gynéco-médicale',
#                                                                          nan,
#                       'Biologie médicale option biologie de la reproduction',
#                           'Santé publique option administration de la santé',
#                                 'Biologie médicale option biologie générale',
#                                              'Pédiatrie option néonatologie',
#                            'Méd cardiovasculaire opt card interventionnelle',
#                          'Méd cardiovasculaire opt imagerie cardio d'expert',
#                           'Méd cardiovasculaire opt rythmo inter stimu card',
#               'Chirurgie pédiatrique option chirurgie viscérale pédiatrique',
#                                   'Pédiatrie option réanimation pédiatrique',
#                        'Biologie médicale option hématologie et immunologie',
#                           'Ophtalmologie opt chir ophtalmopéd strabologique',
#                                           'Pédiatrie option pneumopédiatrie',
#                         'Psychiatrie option psychiatrie de la personne âgée',
#                          'Néphrologie option soins intensifs néphrologiques',
#  'Biologie médicale option médecine moléculaire, génétique et pharmacologie',
#                                            'Pédiatrie option neuropédiatrie',
#                             'ORL - chir cervico-faciale opt audiophonologie',
#                         'Médecine intensive-réanimation opt réa pédiatrique',
#                                 'Biologie médicale option agents infectieux',
#                           'Pneumologie option soins intensifs respiratoires',
#                          'Anesthésie-réanimation opt anesthésie-pédiatrique',
#                             'Chirurgie viscérale et digestive opt endo chir',
#                           'Neurologie opt trait interv ischémie céréb aigüe']
# Length: 95, dtype: str

# %%
generalistes = medecins[
    medecins["Libellé savoir-faire"].isin(
        [
            "Médecine Générale",
            "Qualifié en Médecine Générale",
            "Spécialiste en Médecine Générale",
        ]
    )
]

# %%
generalistes.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 190500 entries, 16 to 2233492
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Libellé civilité d'exercice              189687 non-null  str
#  1   Libellé civilité                         190500 non-null  str
#  2   Nom d'exercice                           190499 non-null  str
#  3   Prénom d'exercice                        190499 non-null  str
#  4   Libellé profession                       190500 non-null  str
#  5   Libellé savoir-faire                     190500 non-null  str
#  6   Code mode exercice                       141352 non-null  str
#  7   Numéro Voie (coord. structure)           105902 non-null  float64
#  8   Libellé type de voie (coord. structure)  47752 non-null   str
#  9   Libellé Voie (coord. structure)          118794 non-null  str
#  10  Code postal (coord. structure)           120503 non-null  str
#  11  Libellé commune (coord. structure)       120499 non-null  str
#  12  Libellé secteur d'activité               120503 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 20.3 MB

# %%
generalistes = generalistes.dropna(
    subset=["Code postal (coord. structure)", "Nom d'exercice"]
)

# %%
generalistes.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 120502 entries, 30 to 2233492
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   Libellé civilité d'exercice              119695 non-null  str
#  1   Libellé civilité                         120502 non-null  str
#  2   Nom d'exercice                           120502 non-null  str
#  3   Prénom d'exercice                        120502 non-null  str
#  4   Libellé profession                       120502 non-null  str
#  5   Libellé savoir-faire                     120502 non-null  str
#  6   Code mode exercice                       120502 non-null  str
#  7   Numéro Voie (coord. structure)           105901 non-null  float64
#  8   Libellé type de voie (coord. structure)  47751 non-null   str
#  9   Libellé Voie (coord. structure)          118793 non-null  str
#  10  Code postal (coord. structure)           120502 non-null  str
#  11  Libellé commune (coord. structure)       120498 non-null  str
#  12  Libellé secteur d'activité               120502 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 12.9 MB

# %%
generalistes[generalistes["Code mode exercice"] == "L"][
    "Libellé secteur d'activité"
].unique()
# Out:
# <StringArray>
# [                              'Cabinet individuel',
#                              'Etab. Privé Non PSPH',
#                               'Exercice en Société',
#                                 'Cabinet de groupe',
#                     'Etablissement Public de santé',
#  'Services départementaux d'incendie et de secours',
#                    'Ministère & Serv. déconcentrés',
#                      'Secteur privé PH temps plein',
#     'Permanence de soins ambulatoires hors cabinet',
#                                  'Centres de santé',
#                                'Secteur non défini',
#                                  'Etab. Privé PSPH',
#                     'Autre établissement Sanitaire',
#                        'Etab. Hébergt Réadaptation']
# Length: 14, dtype: str

# %%
secteurs_ville = [
    "Cabinet individuel",
    "Cabinet de groupe",
    "Exercice en Société",
    "Centres de santé",
]
generalistes_ville = generalistes[
    (generalistes["Code mode exercice"] == "L")
    & generalistes["Libellé secteur d'activité"].isin(secteurs_ville)
]

# %%
generalistes_ville.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 64690 entries, 44 to 2232012
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Libellé civilité d'exercice              64690 non-null  str
#  1   Libellé civilité                         64690 non-null  str
#  2   Nom d'exercice                           64690 non-null  str
#  3   Prénom d'exercice                        64690 non-null  str
#  4   Libellé profession                       64690 non-null  str
#  5   Libellé savoir-faire                     64690 non-null  str
#  6   Code mode exercice                       64690 non-null  str
#  7   Numéro Voie (coord. structure)           60199 non-null  float64
#  8   Libellé type de voie (coord. structure)  1 non-null      str
#  9   Libellé Voie (coord. structure)          63906 non-null  str
#  10  Code postal (coord. structure)           64690 non-null  str
#  11  Libellé commune (coord. structure)       64688 non-null  str
#  12  Libellé secteur d'activité               64690 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 6.9 MB

# %%
generalistes_ville_idf = generalistes_ville[
    generalistes_ville["Code postal (coord. structure)"].str.startswith(
        ("75", "92", "93", "94", "77", "91", "78", "95")
    )
]

# %%
generalistes_ville_idf.count()
# Out:
# Libellé civilité d'exercice                9530
# Libellé civilité                           9530
# Nom d'exercice                             9530
# Prénom d'exercice                          9530
# Libellé profession                         9530
# Libellé savoir-faire                       9530
# Code mode exercice                         9530
# Numéro Voie (coord. structure)             9338
# Libellé type de voie (coord. structure)       0
# Libellé Voie (coord. structure)            9511
# Code postal (coord. structure)             9530
# Libellé commune (coord. structure)         9530
# Libellé secteur d'activité                 9530
# dtype: int64

# %%
generalistes_ville_idf["Numéro Voie (coord. structure)"] = (
    generalistes_ville_idf["Numéro Voie (coord. structure)"].astype("Int64").astype(str)
)

# %%
generalistes_ville_idf.dtypes
# Out:
# Libellé civilité d'exercice                str
# Libellé civilité                           str
# Nom d'exercice                             str
# Prénom d'exercice                          str
# Libellé profession                         str
# Libellé savoir-faire                       str
# Code mode exercice                         str
# Numéro Voie (coord. structure)             str
# Libellé type de voie (coord. structure)    str
# Libellé Voie (coord. structure)            str
# Code postal (coord. structure)             str
# Libellé commune (coord. structure)         str
# Libellé secteur d'activité                 str
# dtype: object

# %%
generalistes_ville_idf["Numéro Voie (coord. structure)"] = generalistes_ville_idf[
    "Numéro Voie (coord. structure)"
].fillna(value="")

# %%
generalistes_ville_idf["Libellé Voie (coord. structure)"] = generalistes_ville_idf[
    "Libellé Voie (coord. structure)"
].fillna("")

# %%
generalistes_ville_idf["adresse"] = (
    generalistes_ville_idf["Numéro Voie (coord. structure)"]
    + " "
    + generalistes_ville_idf["Libellé Voie (coord. structure)"]
    + " "
    + generalistes_ville_idf["Code postal (coord. structure)"]
    + " "
    + generalistes_ville_idf["Libellé commune (coord. structure)"]
)

# %%
generalistes_ville_idf["adresse"].isna().sum()
# Out:
# np.int64(0)

# %%
generalistes_ville_idf["Libellé Voie (coord. structure)"]
# Out:
# 776                  AVENUE D ITALIE
# 872                   RUE DE BELFORT
# 897                    RUE DE RENNES
# 949        RUE NOTRE DAME DES CHAMPS
# 998                        RUE DUTOT
#                      ...
# 2206971      BOULEVARD DE BELLEVILLE
# 2214120          RUE ARISTIDE BRIAND
# 2218798                AVENUE VAUBAN
# 2219985       RUE DU GENERAL LECLERC
# 2221500            ROUTE DE CONFLANS
# Name: Libellé Voie (coord. structure), Length: 9530, dtype: str

# %%
generalistes_ville_idf.iloc[1000]
# Out:
# Libellé civilité d'exercice                                               Docteur
# Libellé civilité                                                         Monsieur
# Nom d'exercice                                                           BRILLANT
# Prénom d'exercice                                                         ANDREAS
# Libellé profession                                                        Médecin
# Libellé savoir-faire                             Spécialiste en Médecine Générale
# Code mode exercice                                                              L
# Numéro Voie (coord. structure)                                                  5
# Libellé type de voie (coord. structure)                                       NaN
# Libellé Voie (coord. structure)                              RUE DU CHAMP GALLOIS
# Code postal (coord. structure)                                              95200
# Libellé commune (coord. structure)                                      Sarcelles
# Libellé secteur d'activité                                    Exercice en Société
# adresse                                    5 RUE DU CHAMP GALLOIS 95200 Sarcelles
# Name: 150010, dtype: str

# %%
generalistes_ville_idf.to_csv("./data/generalistes_ville_idf.csv")
